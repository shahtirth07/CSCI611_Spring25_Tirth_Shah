# %%
from ultralytics import YOLO

model = YOLO("model1.pt")

results = model("v2.MP4", conf=0.5, save=True, imgsz=640)

for r in results:
    boxes = r.boxes
    masks = r.masks
    probs = r.probs
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/2748) c:\Users\tshah\OneDrive - California State University Chico\Desktop\CourseWork\CSCI611\assignment3\v2.MP4: 384x640 3 cars, 1 traffic light, 103.1ms
# video 1/1 (frame 2/2748) c:\Users\tshah\OneDrive - California State University Chico\Desktop\CourseWork\CSCI611\assignment3\v2.MP4: 384x640 3 cars, 1 traffic light, 80.1ms
# ...
